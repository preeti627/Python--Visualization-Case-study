# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seabor graphs to a better style
sns.set(style="ticks")

# %%
#importing the file as sales_data
sales_data=pd.read_csv(r"C:\Users\preet\Downloads\Python Foundation Case Study 4 - Python Visualization Case Study (1)\SalesData.csv")

# %%
sales_data
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %%
#checking for duplicate values
sales_data.duplicated().sum()
# Out:
# 0

# %%
#checking for null values
sales_data.isna().sum()
# Out:
# AccountId             0
# AccountName           0
# Region                0
# Division              0
# City                  0
# State                 0
# Tier                  0
# Month                 0
# Sales2015             0
# Sales2016             0
# Units2015             0
# Units2016             0
# TargetAchevied2015    0
# TargetAchevied2016    0
# dtype: int64

# %% [markdown]
# # Q1. Compare Sales by region for 2016 with 2015 using bar chart

# %%
dt= sales_data.groupby("Region")["Sales2015","Sales2016"].sum()
dt
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_18796\4269005133.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dt= sales_data.groupby("Region")["Sales2015","Sales2016"].sum()
#             Sales2015     Sales2016
# Region
# Central  7.891729e+06  9.787809e+06
# East     9.512916e+06  1.266723e+07
# West     5.349745e+06  7.209689e+06

# %%
dt.plot(kind= 'bar',figsize=(7,5))
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
print("we can conclude that sales in 2016 was always higher than sales in 2015 and region with most sales in both year is EAST")
# Out:
# we can conclude that sales in 2016 was always higher than sales in 2015 and region with most sales in both year is EAST

# %% [markdown]
# # Q2. What are the contributing factors to the sales for each region in 2016. Visualize it using a Pie Chart.

# %%
df=sales_data.groupby(by= 'Region').Sales2016.sum().reset_index()

# %%
plt.figure(figsize=(6,6))
plt.pie('Sales2016' , labels='Region',data= df, autopct="%.2f%%")
plt.show()

# %%
print("The most contributing factor to the sales in 2016 is EAST region with 42.70% sales")
# Out:
# The most contributing factor to the sales in 2016 is EAST region with 42.70% sales

# %% [markdown]
# # Q3. Compare the total sales of 2015 and 2016 with respect to Region and Tiers

# %%
dt1= sales_data.groupby(["Tier","Region"])["Sales2015","Sales2016"].sum()
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_18796\496511015.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dt1= sales_data.groupby(["Tier","Region"])["Sales2015","Sales2016"].sum()

# %%
dt1.plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Tier,Region'>

# %%
print("by the above figure , we can conclude that EAST Region with HIGH tier has most sales in 2016 ")
# Out:
# by the above figure , we can conclude that EAST Region with HIGH tier has most sales in 2016

# %% [markdown]
# # Q4. In East region, which state registered a decline in 2016 as compared to 2015?

# %%
m= sales_data[sales_data.Region=='East'].groupby('State')["Sales2015","Sales2016"].sum()
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_18796\2672348264.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   m= sales_data[sales_data.Region=='East'].groupby('State')["Sales2015","Sales2016"].sum()

# %%
m.plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='State'>

# %%
print(" In East region, NY state registered a decline in 2016 as compared to 2015.")
# Out:
#  In East region, NY state registered a decline in 2016 as compared to 2015.

# %% [markdown]
# # Q5. In all the High tier, which Division saw a decline in number of units sold in 2016 compared to 2015?

# %%
n= sales_data[sales_data.Tier=='High'].groupby('Division')["Sales2015","Sales2016"].sum()
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_18796\4027281507.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   n= sales_data[sales_data.Tier=='High'].groupby('Division')["Sales2015","Sales2016"].sum()

# %%
n.plot(kind= 'bar', figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Division'>

# %%
print("From the above figure, we can conclude that n all the High tier NONE of the Divisions saw a decline in the number",
      "of units sold in 2016 compared to 2015.")
# Out:
# From the above figure, we can conclude that n all the High tier NONE of the Divisions saw a decline in the number of units sold in 2016 compared to 2015.

# %% [markdown]
# # Q6. Create a new column Qtr using numpy.where() or any suitable utility in the imported dataset. The Quarters are based on months and defined as -
# * Jan - Mar : Q1
# * Apr - Jun : Q2
# * Jul - Sep : Q3
# * Oct - Dec : Q4

# %%
sales_data.loc[(sales_data.Month== 'Jan')|(sales_data.Month== 'Feb') | (sales_data.Month== 'Mar' ),'Qtr'] = 'Q1'
sales_data.loc[(sales_data.Month== 'Apr')|(sales_data.Month== 'May' )| (sales_data.Month== 'Jun'),'Qtr'] = 'Q2'
sales_data.loc[(sales_data.Month== 'Jul')|(sales_data.Month== 'Aug' )|( sales_data.Month== 'Sep'),'Qtr'] = 'Q3'
sales_data.loc[(sales_data.Month== 'Oct')|(sales_data.Month== 'Nov' )|( sales_data.Month== 'Dec' ),'Qtr'] = 'Q4'

# %% [markdown]
# # Q7. Compare Qtr wise sales in 2015 and 2016 in a bar plot

# %%
d=sales_data.groupby('Qtr')["Sales2015","Sales2016"].sum()
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_18796\1433492928.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   d=sales_data.groupby('Qtr')["Sales2015","Sales2016"].sum()

# %%
d.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Qtr'>

# %%
print("In above chart, sales of Qtr in 2016 is more than sales of quarter in 2015.")
# Out:
# In above chart, sales of Qtr in 2016 is more than sales of quarter in 2015.

# %% [markdown]
# # Q8. Determine the composition of Qtr wise sales in and 2016 with regards to all the Tiers in a pie chart.

# %%
q=sales_data[(sales_data.Tier=='High')|(sales_data.Tier=='Low')|(sales_data.Tier=='Med')].groupby(['Qtr','Tier']).Sales2016.sum().reset_index()
q= pd.pivot_table(data= q,index='Tier', values='Sales2016', columns='Qtr')

# %%
q.plot(kind= 'pie',x= 'Sales2016',subplots= True, figsize= (20,20), autopct="%.2f%%")
# Out:
# array([<AxesSubplot:ylabel='Q1'>, <AxesSubplot:ylabel='Q2'>,
#        <AxesSubplot:ylabel='Q3'>, <AxesSubplot:ylabel='Q4'>], dtype=object)

# %%
print("Above chart clearly shows that in every quarter, tier (HIGH) is more than the other two",
      "combined , i.e. always above 50 percent and in Q3 &Q4 it is more than 60%.")
# Out:
# Above chart clearly shows that in every quarter, tier (HIGH) is more than the other two combined , i.e. always above 50 percent and in Q3 &Q4 it is more than 60%.
